# %% [markdown]
# <a href="https://colab.research.google.com/github/Vietzanh/Computer_Architecture_Lab-MIPS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install vnstock

# %%
pip install pandas

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

worksheet = gc.open('Your spreadsheet name').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/gspread/client.py in open(self, title)
#     119         try:
# --> 120             properties = finditem(
#     121                 lambda x: x['name'] == title,
#
# /usr/local/lib/python3.10/dist-packages/gspread/utils.py in finditem(func, seq)
#      93     """
# ---> 94     return next((item for item in seq if func(item)))
#      95
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# SpreadsheetNotFound                       Traceback (most recent call last)
# <ipython-input-3-f4e8adf730a4> in <cell line: 10>()
#       8 gc = gspread.authorize(creds)
#       9
# ---> 10 worksheet = gc.open('Your spreadsheet name').sheet1
#      11
#      12 # get_all_values gives a list of rows.
#
# ...

# %%
import pandas as pd
pd.read_csv('/content/drive/MyDrive/meal_info.csv')
# Out:
#     meal_id      category      cuisine
# 0      1885     Beverages         Thai
# 1      1993     Beverages         Thai
# 2      2539     Beverages         Thai
# 3      1248     Beverages       Indian
# 4      2631     Beverages       Indian
# 5      1311        Extras         Thai
# 6      1062     Beverages      Italian
# 7      1778     Beverages      Italian
# 8      1803        Extras         Thai
# 9      1198        Extras         Thai
# 10     2707     Beverages      Italian
# 11     1847          Soup         Thai
# 12     1438          Soup         Thai
# 13     2494          Soup         Thai
# 14     2760  Other Snacks         Thai
# 15     2490         Salad      Italian
# 16     1109     Rice Bowl       Indian
# 17     2290     Rice Bowl       Indian
# 18     1525  Other Snacks         Thai
# 19     2704  Other Snacks         Thai
# 20     1878      Starters         Thai
# 21     2640      Starters         Thai
# 22     2577      Starters         Thai
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_1.groupby('cuisine').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['meal_id'].plot(kind='hist', bins=20, title='meal_id')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # I. Giới thiệu
# ## 1. OMG
